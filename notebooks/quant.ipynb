# %%
import numpy as np

# %%
import nibabel as nib

# %%
lh = nib.load('/RAID1/jupytertmp/mcm/data/cmrglc-maps/quant-cmrglc_desc-10frames_hemi-lh_space-fsaverage_pet.mgh').get_fdata().squeeze()
rh = nib.load('/RAID1/jupytertmp/mcm/data/cmrglc-maps/quant-cmrglc_desc-10frames_hemi-rh_space-fsaverage_pet.mgh').get_fdata().squeeze()

# %%
nib.freesurfer.write_morph_data('/RAID1/jupytertmp/mcm/data/cmrglc-maps/test-lh.func.gii', lh)

# %%
gifti = nib.load('/RAID1/jupytertmp/mcm/test.func.gii').agg_data()

# %%
gifti
# Out:
# array([27.600882, 30.388515, 34.169056, ..., 25.231623, 25.060888,
#        24.161276], shape=(163842,), dtype=float32)
